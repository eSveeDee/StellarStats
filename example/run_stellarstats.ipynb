# %% [markdown]
# ### **Notebook to run StellarStats bulk analysis**

# %% [markdown]
# ##### **Optimize segmentation parameters**
#
# Values of interest for the segmentation are:
#
# - diameter: default is None, which let's programme detect size by itself, but can be overwritten to force cell diameter. Provide in pixels.
# - flow_threshold: threshold on flow error to accept a mask (set higher to get more cells, e.g. in range from (0.1, 3.0), OR set to 0.0 to turn off so no cells discarded)
# - cell_prob_threshold: threshold on cellprob output to seed cell masks (set lower to include more pixels or higher to include fewer, e.g. in range from (-6, 6))

# %%
# %run ../stellarstats_segment_single.py --tiff "data/440/230630_FRL+WL_Cthrm_G1_pos2_440_3nm_20nm.tif"  --use_gpu --trial
# Out:
# Saved MIP image to data/440/MIPs/230630_FRL+WL_Cthrm_G1_pos2_440_3nm_20nm_MIP.tif

# %%
# %run ../stellarstats_segment_single.py --tiff "data/440/230630_FRL+WL_Cthrm_G1_pos2_440_3nm_20nm.tif"  --use_gpu
# Out:
# Saved MIP image to data/440/MIPs/230630_FRL+WL_Cthrm_G1_pos2_440_3nm_20nm_MIP.tif
# Segmentation saved to data/440/Masks/230630_FRL+WL_Cthrm_G1_pos2_440_3nm_20nm_MIP.npy and data/440/Masks/230630_FRL+WL_Cthrm_G1_pos2_440_3nm_20nm_MIP.png

# %%
# %run ../stellarstats_analyse_single.py -p "data/440/" -i  "data/440/230630_FRL+WL_Cthrm_G1_pos2_440_3nm_20nm.tif" -m "data/440/MetaData/230630_FRL+WL_Cthrm_G1_pos2_440_3nm_20nm_Properties.xml" --plot_normalized_intensity --ratio_histogram --range1 715 735 --range2 745 765

# %%
# %run ../stellarstats_analyse_single.py -p "data/440/" -i  "data/440/230630_FRL+WL_Cthrm_G1_pos2_440_3nm_20nm.tif" -m "data/440/MetaData/230630_FRL+WL_Cthrm_G1_pos2_440_3nm_20nm_Properties.xml" --range1 715 735 --range2 745 765 --ratio_mask --vmax 2.5

# %% [markdown]
# ##### **Segment in batch:**
#
# Provide your image directory, assuming all tiff files are lambda scans and your metadata is collected in a folder called `MetaData`.

# %%
input_dir = "data/440/"

# %%
# %run ../stellarstats_segment_batch.py -i {input_dir} --use_gpu
# Out:
# Processing file: data/440/230630_FRL+WL_Cthrm_G1_pos2_440_3nm_20nm.tif
# MIP file already exists: data/440/MIPs/230630_FRL+WL_Cthrm_G1_pos2_440_3nm_20nm_MIP.tif. Skipping projection.
# Segmentation saved to data/440/Masks/230630_FRL+WL_Cthrm_G1_pos2_440_3nm_20nm_MIP.npy and data/440/Masks/230630_FRL+WL_Cthrm_G1_pos2_440_3nm_20nm_MIP.png
# Segmentation saved for data/440/230630_FRL+WL_Cthrm_G1_pos2_440_3nm_20nm.tif

# %%
# %run ../stellarstats_analyse_batch.py -p {input_dir}  --plot_normalized_intensity --shape_metrics --save_output
# Out:
# Processing file: 230630_FRL+WL_Cthrm_G1_pos2_440_3nm_20nm_MIP_seg.npy
# Saved cell sizes to data/440/combined_cell_sizes.csv
# Saved combined intensity data to data/440/combined_intensity_data.csv
# Saved normalized combined intensity plot to data/440/normalized_combined_intensity_plot.svg
